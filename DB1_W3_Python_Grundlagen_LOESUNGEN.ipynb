# %% [markdown]
# <a href="https://colab.research.google.com/github/louistrue/DB-1/blob/main/DB1_W3_Python_Grundlagen_LOESUNGEN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏗️ Digitales Bauen 1: Python Grundlagen
# ## Das Minimum, um loszulegen
# ### 🔑 LÖSUNGEN
#
# **Berner Fachhochschule** | Architektur, Holz und Bau | BSc Bauingenieurwesen
#
# ---
#
# Dieses Notebook ist euer **Nachschlagewerk** für die Python-Grundlagen.
# Arbeitet es von oben nach unten durch – jedes Konzept baut auf dem vorherigen auf.
#
# - **Teil 1:** Erste Schritte – `print()`, Variablen, Datentypen
# - **Teil 2:** Rechnen und Text – Operatoren, f-Strings
# - **Teil 3:** Entscheidungen und Wiederholungen – `if/else`, `for`
# - **Teil 4:** Struktur – Listen, Funktionen
#
# Zellen mit **✏️ Aufgabe** müsst ihr selbst ergänzen.

# %% [markdown]
# ### So funktioniert Google Colab
#
# Colab ist ein **Notebook im Browser** – ihr braucht nichts zu installieren.
#
# - Jede graue Box ist eine **Zelle** mit Code
# - Zum Ausführen: **Play-Button ▶** links neben der Zelle, oder **Shift + Enter**
# - Die Ausgabe erscheint direkt darunter
# - Ihr könnt den Code in jeder Zelle ändern und erneut ausführen
# - Zellen werden **nacheinander** ausgeführt – von oben nach unten

# %% [markdown]
# ---
# # Teil 1: Erste Schritte
#
# ## 1.1 `print()` – Text ausgeben
#
# Der einfachste Befehl in Python: Etwas auf den Bildschirm schreiben.

# %%
print("Hallo, Bauingenieurin!")
print("Willkommen in Python.")

# %% [markdown]
# - `print()` gibt Text aus
# - Text steht in **Anführungszeichen** (`"..."` oder `'...'`)
# - Jeder `print()`-Aufruf erzeugt eine **neue Zeile**

# %% [markdown]
# ## 1.2 Variablen – Werte speichern
#
# Eine Variable ist ein **Name für einen Wert**. Wie ein beschriftetes Regal auf der Baustelle.

# %%
# Masse eines Holzbalkens
breite = 12      # cm
hoehe = 24       # cm
laenge = 500     # cm

print("Balken:", breite, "x", hoehe, "x", laenge, "cm")

# %% [markdown]
# **Regeln für Variablennamen:**
# - Nur Buchstaben, Zahlen und `_` (Unterstrich)
# - Darf **nicht** mit einer Zahl beginnen
# - Klein geschrieben, Wörter mit `_` getrennt: `raum_hoehe`, `last_kn`
# - Keine Umlaute (ä, ö, ü) – besser `hoehe` statt `höhe`

# %% [markdown]
# ## 1.3 Datentypen – Was Python speichert
#
# Python kennt verschiedene **Arten von Werten**. Die vier wichtigsten:

# %%
# Die vier wichtigsten Datentypen

anzahl_stuetzen = 4              # int   (ganze Zahl)
spannweite_m = 7.5               # float (Dezimalzahl)
material = "Beton C25/30"        # str   (Text)
nachweis_ok = True               # bool  (Wahrheitswert: True/False)

print("Anzahl Stützen:", anzahl_stuetzen, "  Typ:", type(anzahl_stuetzen).__name__)
print("Spannweite:", spannweite_m, "m", "     Typ:", type(spannweite_m).__name__)
print("Material:", material, "   Typ:", type(material).__name__)
print("Nachweis OK:", nachweis_ok, "      Typ:", type(nachweis_ok).__name__)

# %% [markdown]
# | Typ | Bedeutung | Beispiel |
# |-----|-----------|----------|
# | `int` | Ganze Zahl | `4`, `-1`, `100` |
# | `float` | Dezimalzahl | `7.5`, `3.14`, `-0.01` |
# | `str` | Text (String) | `"Beton"`, `'Holz'` |
# | `bool` | Wahrheitswert | `True`, `False` |
#
# Python erkennt den Typ **automatisch** anhand des Wertes.

# %% [markdown]
# ### ✏️ Aufgabe 1: Variablen anlegen
#
# Erstellt Variablen für eine Betonstütze:
# - Breite: 30 cm (ganze Zahl)
# - Höhe: 30 cm (ganze Zahl)
# - Länge: 3.20 m (Dezimalzahl)
# - Material: "Beton C30/37" (Text)
#
# Gebt alle Werte mit `print()` aus.

# %%
# Aufgabe 1: Betonstuetze

breite_cm = 30
hoehe_cm = 30
laenge_m = 3.20
material = "Beton C30/37"

print(f"Breite:   {breite_cm} cm")
print(f"Hoehe:    {hoehe_cm} cm")
print(f"Laenge:   {laenge_m} m")
print(f"Material: {material}")

# %% [markdown]
# ---
# # Teil 2: Rechnen und Text
#
# ## 2.1 Rechenoperatoren
#
# Python ist ein Taschenrechner – nur mächtiger.

# %%
a = 10
b = 3

print("Addition:      ", a + b)      # 13
print("Subtraktion:   ", a - b)      # 7
print("Multiplikation:", a * b)      # 30
print("Division:      ", a / b)      # 3.333...
print("Ganzzahldiv.:  ", a // b)     # 3
print("Rest (Modulo): ", a % b)      # 1
print("Potenz:        ", a ** 2)     # 100

# %% [markdown]
# | Operator | Bedeutung | Beispiel |
# |----------|-----------|----------|
# | `+` | Addition | `5 + 3` → `8` |
# | `-` | Subtraktion | `5 - 3` → `2` |
# | `*` | Multiplikation | `5 * 3` → `15` |
# | `/` | Division | `5 / 3` → `1.667` |
# | `//` | Ganzzahldivision | `5 // 3` → `1` |
# | `%` | Rest (Modulo) | `5 % 3` → `2` |
# | `**` | Potenz | `5 ** 3` → `125` |

# %% [markdown]
# ### Praxisbeispiel: Flächenträgheitsmoment
#
# Das Flächenträgheitsmoment eines Rechteckquerschnitts:
#
# $$I_y = \frac{b \cdot h^3}{12}$$

# %%
# Flaechentraegheitsmoment Rechteckquerschnitt

b = 12   # Breite in cm
h = 24   # Hoehe in cm

I_y = b * h**3 / 12

print("Querschnitt:", b, "x", h, "cm")
print("I_y =", I_y, "cm⁴")

# %% [markdown]
# ## 2.2 f-Strings – Text und Variablen kombinieren
#
# Mit **f-Strings** könnt ihr Variablen direkt in Text einbauen. Setzt ein `f` vor die Anführungszeichen und schreibt Variablen in geschweifte Klammern `{}`.

# %%
b = 12
h = 24
I_y = b * h**3 / 12

# Ohne f-String (umständlich)
print("I_y = " + str(I_y) + " cm⁴")

# Mit f-String (elegant)
print(f"Querschnitt: {b} x {h} cm")
print(f"I_y = {I_y:,.0f} cm⁴")       # :,.0f = Tausendertrennzeichen, 0 Dezimalstellen

# %% [markdown]
# **Formatierung in f-Strings:**
#
# | Format | Bedeutung | Beispiel |
# |--------|-----------|----------|
# | `{x}` | Wert direkt | `12` |
# | `{x:.2f}` | 2 Dezimalstellen | `12.00` |
# | `{x:,.0f}` | Tausendertrenner, 0 Dezimalen | `13,824` |
# | `{x:.1%}` | Prozent mit 1 Dezimale | `75.0%` |

# %% [markdown]
# ### ✏️ Aufgabe 2: Querschnittsfläche und Spannung
#
# Eine Betonstütze hat einen Querschnitt von 30 × 30 cm und trägt eine Normalkraft von 450 kN.
#
# Berechnet:
# 1. Die Querschnittsfläche $A$ in cm²
# 2. Die Spannung $\sigma = \frac{N}{A}$ in kN/cm² und in MPa (1 kN/cm² = 10 MPa)
#
# Gebt die Ergebnisse mit f-Strings formatiert aus (1 Dezimalstelle).

# %%
# Aufgabe 2: Querschnittsflaeche und Spannung

breite_cm = 30
hoehe_cm = 30
last_kn = 450

# Querschnittsflaeche
A_cm2 = breite_cm * hoehe_cm

# Spannung
sigma_kn_cm2 = last_kn / A_cm2
sigma_mpa = sigma_kn_cm2 * 10

print(f"Querschnitt:  {breite_cm} x {hoehe_cm} cm")
print(f"Flaeche A:    {A_cm2} cm²")
print(f"Normalkraft:  {last_kn} kN")
print(f"Spannung:     {sigma_kn_cm2:.1f} kN/cm² = {sigma_mpa:.1f} MPa")

# %% [markdown]
# ## 2.3 Kommentare
#
# Kommentare erklären euren Code – für euch selbst und für andere. Python ignoriert alles nach `#`.

# %%
# Dies ist ein Kommentar (ganze Zeile)

spannweite = 6.5   # Spannweite in Metern (nach Kommentar)

# Guter Kommentar: erklaert WARUM
# Sicherheitsfaktor 1.5 gemaess SIA 260
gamma = 1.5

# Schlechter Kommentar: wiederholt nur den Code
# gamma wird auf 1.5 gesetzt   ← unnötig!

# %% [markdown]
# ---
# # Teil 3: Entscheidungen und Wiederholungen
#
# ## 3.1 Vergleichsoperatoren
#
# Bevor wir Entscheidungen treffen, müssen wir Werte vergleichen können.

# %%
x = 25
y = 30

print(f"{x} == {y} : {x == y}")    # gleich?
print(f"{x} != {y} : {x != y}")    # ungleich?
print(f"{x} <  {y} : {x < y}")     # kleiner?
print(f"{x} >  {y} : {x > y}")     # groesser?
print(f"{x} <= {y} : {x <= y}")    # kleiner oder gleich?
print(f"{x} >= {y} : {x >= y}")    # groesser oder gleich?

# %% [markdown]
# | Operator | Bedeutung | Beispiel |
# |----------|-----------|----------|
# | `==` | gleich | `5 == 5` → `True` |
# | `!=` | ungleich | `5 != 3` → `True` |
# | `<` | kleiner als | `3 < 5` → `True` |
# | `>` | grösser als | `5 > 3` → `True` |
# | `<=` | kleiner oder gleich | `5 <= 5` → `True` |
# | `>=` | grösser oder gleich | `5 >= 6` → `False` |
#
# **Achtung:** `=` ist Zuweisung, `==` ist Vergleich!

# %% [markdown]
# ## 3.2 `if / elif / else` – Entscheidungen treffen
#
# Mit Bedingungen reagiert euer Programm auf verschiedene Situationen.

# %%
# Plausibilitaetspruefung: Betonplattendicke

dicke_cm = 18
mindest_dicke = 20

if dicke_cm >= mindest_dicke:
    print(f"✅ {dicke_cm} cm: Mindestdicke eingehalten")
else:
    print(f"❌ {dicke_cm} cm: Zu dünn! Minimum ist {mindest_dicke} cm")

# %% [markdown]
# **Wichtig:** Der Code-Block nach `if`, `elif` oder `else` wird **eingerückt** (4 Leerzeichen). Die Einrückung zeigt Python, welcher Code zur Bedingung gehört.

# %%
# Mehrere Bedingungen mit elif

raumhoehe = 2.35  # Testet auch mit 2.70 und 2.10
nutzung = "Wohnraum"

# Mindesthoehen nach Nutzung
if nutzung == "Wohnraum":
    mindest = 2.40
elif nutzung == "Büro":
    mindest = 2.50
elif nutzung == "Lager":
    mindest = 2.20
else:
    mindest = 2.40
    print(f"⚠️ Nutzung '{nutzung}' unbekannt, verwende Standard 2.40 m")

if raumhoehe >= mindest:
    print(f"✅ {nutzung}: {raumhoehe} m >= {mindest} m")
else:
    differenz = mindest - raumhoehe
    print(f"❌ {nutzung}: {raumhoehe} m < {mindest} m (fehlen {differenz:.2f} m)")

# %% [markdown]
# **Aufbau:**
# ```python
# if bedingung_1:
#     # wird ausgeführt wenn bedingung_1 True ist
# elif bedingung_2:
#     # wird ausgeführt wenn bedingung_2 True ist
# else:
#     # wird ausgeführt wenn keine Bedingung True ist
# ```
# - `elif` und `else` sind **optional**
# - Es können beliebig viele `elif`-Blöcke verwendet werden

# %% [markdown]
# ### ✏️ Aufgabe 3: Holzklasse bestimmen
#
# Schreibt ein Programm, das anhand der **Biegefestigkeit** die Festigkeitsklasse von Nadelholz bestimmt:
#
# | Biegefestigkeit (MPa) | Klasse |
# |-----------------------|--------|
# | < 14 | Nicht klassifiziert |
# | 14–19 | C14 |
# | 20–27 | C24 |
# | ≥ 28 | C30 oder höher |
#
# Testet mit den Werten 12, 18, 24 und 35.

# %%
# Aufgabe 3: Festigkeitsklasse bestimmen

biegefestigkeit = 24  # Testet auch mit 12, 18, 35

if biegefestigkeit < 14:
    klasse = "Nicht klassifiziert"
elif biegefestigkeit <= 19:
    klasse = "C14"
elif biegefestigkeit <= 27:
    klasse = "C24"
else:
    klasse = "C30 oder hoeher"

print(f"Biegefestigkeit: {biegefestigkeit} MPa → Klasse: {klasse}")

# %% [markdown]
# ## 3.3 `for`-Schleife – Systematisch wiederholen
#
# Statt denselben Code 10x zu kopieren, lässt man den Computer wiederholen.

# %%
# Grundform: über eine Liste iterieren

hoehen = [16, 20, 24, 28, 32]

for h in hoehen:
    print(f"Hoehe: {h} cm")

# %%
# range() erzeugt eine Zahlenfolge

print("range(5):       ", list(range(5)))         # 0, 1, 2, 3, 4
print("range(1, 6):    ", list(range(1, 6)))      # 1, 2, 3, 4, 5
print("range(0, 50, 10):", list(range(0, 50, 10)))  # 0, 10, 20, 30, 40

# %%
# Praxisbeispiel: I_y für verschiedene Balkenhöhen

b = 12  # Breite fix in cm

print(f"Breite b = {b} cm")
print()
print("  h [cm]  |  I_y [cm⁴]")
print("-" * 28)

for h in range(16, 44, 4):       # 16, 20, 24, ..., 40
    I_y = b * h**3 / 12
    print(f"    {h:>2}    |   {I_y:>9,.0f}")

# %% [markdown]
# ### ✏️ Aufgabe 4: Materialmengen berechnen
#
# Auf einer Baustelle werden Betonstützen mit quadratischem Querschnitt (30 × 30 cm) gegossen. Die Höhe variiert je nach Geschoss.
#
# Berechnet für jedes Geschoss das **Betonvolumen** in m³:
#
# $$V = \frac{b \cdot h \cdot l}{1\,000\,000} \text{ (cm³ } \rightarrow \text{ m³)}$$
#
# Geschosshöhen: 320, 300, 300, 280, 280 cm (EG bis 4. OG)
#
# Gebt am Ende auch das **Gesamtvolumen** aus.

# %%
# Aufgabe 4: Betonvolumen pro Geschoss

b_cm = 30
h_cm = 30
geschosshoehen = [320, 300, 300, 280, 280]   # in cm
namen = ["EG", "1.OG", "2.OG", "3.OG", "4.OG"]

gesamt_m3 = 0

print(f"Stuetze: {b_cm} x {h_cm} cm")
print()

for i in range(len(geschosshoehen)):
    vol_m3 = b_cm * h_cm * geschosshoehen[i] / 1_000_000
    gesamt_m3 = gesamt_m3 + vol_m3
    print(f"  {namen[i]:>4}: Hoehe {geschosshoehen[i]} cm → V = {vol_m3:.3f} m³")

print()
print(f"  Gesamtvolumen: {gesamt_m3:.3f} m³")

# %% [markdown]
# ---
# # Teil 4: Struktur
#
# ## 4.1 Listen – Mehrere Werte speichern
#
# Eine Liste speichert **mehrere Werte in einer Variable**. Wie ein Ordner mit nummerierten Seiten.

# %%
# Liste erstellen
lasten = [120, 85, 95, 200, 150]   # kN

# Einzelne Elemente (Index startet bei 0!)
print("Erstes Element: ", lasten[0])    # 120
print("Zweites Element:", lasten[1])    # 85
print("Letztes Element:", lasten[-1])   # 150

# Anzahl Elemente
print("Anzahl:", len(lasten))

# Element hinzufügen
lasten.append(175)
print("Nach append:", lasten)

# %% [markdown]
# | Operation | Code | Ergebnis |
# |-----------|------|----------|
# | Erstellen | `[1, 2, 3]` | Liste mit 3 Elementen |
# | Zugriff | `liste[0]` | Erstes Element |
# | Letztes | `liste[-1]` | Letztes Element |
# | Länge | `len(liste)` | Anzahl Elemente |
# | Hinzufügen | `liste.append(x)` | Element anfügen |
# | Summe | `sum(liste)` | Summe aller Elemente |
# | Minimum | `min(liste)` | Kleinstes Element |
# | Maximum | `max(liste)` | Grösstes Element |

# %%
# Nuetzliche Funktionen für Listen

lasten = [120, 85, 95, 200, 150]

print(f"Lasten:  {lasten} kN")
print(f"Summe:   {sum(lasten)} kN")
print(f"Minimum: {min(lasten)} kN")
print(f"Maximum: {max(lasten)} kN")
print(f"Mittel:  {sum(lasten) / len(lasten):.1f} kN")

# %% [markdown]
# ## 4.2 Funktionen – Code wiederverwenden
#
# Eine Funktion ist ein **benannter Code-Block**, den ihr beliebig oft aufrufen könnt. Wie eine Formel, die ihr einmal definiert und dann immer wieder anwendet.

# %%
# Funktion definieren
def flaechentraegheitsmoment(b, h):
    """Berechnet I_y eines Rechteckquerschnitts in cm⁴."""
    return b * h**3 / 12

# Funktion aufrufen
ergebnis = flaechentraegheitsmoment(12, 24)
print(f"I_y = {ergebnis:,.0f} cm⁴")

# Mehrfach verwenden
print(f"I_y(10, 20) = {flaechentraegheitsmoment(10, 20):,.0f} cm⁴")
print(f"I_y(16, 32) = {flaechentraegheitsmoment(16, 32):,.0f} cm⁴")

# %% [markdown]
# **Aufbau einer Funktion:**
# ```python
# def funktionsname(parameter1, parameter2):
#     """Kurze Beschreibung (optional)."""
#     # Berechnung
#     ergebnis = ...
#     return ergebnis
# ```
# - `def` leitet die Definition ein
# - **Parameter** sind die Eingabewerte (in Klammern)
# - `return` gibt das Ergebnis zurück

# %%
# Funktion mit Bedingung

def pruefe_dicke(dicke_cm, mindest_cm=20):
    """Prüft ob eine Betonplatte die Mindestdicke einhält."""
    if dicke_cm >= mindest_cm:
        return f"✅ {dicke_cm} cm: OK"
    else:
        return f"❌ {dicke_cm} cm: Zu dünn (min. {mindest_cm} cm)"

# Verschiedene Platten prüfen
for dicke in [15, 18, 20, 22, 25]:
    print(pruefe_dicke(dicke))

# %% [markdown]
# ### ✏️ Aufgabe 5: Eigene Funktion schreiben
#
# Schreibt eine Funktion `betonvolumen(b_cm, h_cm, l_cm)`, die das Volumen einer Stütze in **m³** berechnet und zurückgibt.
#
# $$V_{m^3} = \frac{b \cdot h \cdot l}{1\,000\,000}$$
#
# Verwendet die Funktion, um das Volumen für folgende Stützen auszugeben:
# - 30 × 30 × 320 cm
# - 40 × 40 × 300 cm
# - 25 × 25 × 280 cm

# %%
# Aufgabe 5: Funktion Betonvolumen

def betonvolumen(b_cm, h_cm, l_cm):
    """Berechnet das Volumen einer Stuetze in m³."""
    return b_cm * h_cm * l_cm / 1_000_000

# Stuetzen berechnen
stuetzen = [
    (30, 30, 320),
    (40, 40, 300),
    (25, 25, 280),
]

for b, h, l in stuetzen:
    vol = betonvolumen(b, h, l)
    print(f"  Stuetze {b}x{h}x{l} cm → V = {vol:.3f} m³")

# %% [markdown]
# ### ✏️ Aufgabe 6: Alles zusammen
#
# Schreibt ein Programm, das für eine Liste von Balkenquerschnitten (b × h in cm) jeweils das Flächenträgheitsmoment $I_y$ berechnet und bewertet:
#
# - $I_y < 10\,000$ cm⁴ → ❌ zu gering
# - $10\,000 \leq I_y \leq 50\,000$ cm⁴ → ✅ Zielbereich
# - $I_y > 50\,000$ cm⁴ → ⚠️ überdimensioniert
#
# Verwendet eine Funktion für die Berechnung und eine für die Bewertung.

# %%
# Aufgabe 6: Querschnitte bewerten

querschnitte = [
    (10, 16),
    (12, 24),
    (14, 28),
    (16, 36),
    (20, 40),
]

def flaechentraegheitsmoment(b, h):
    """Berechnet I_y eines Rechteckquerschnitts in cm⁴."""
    return b * h**3 / 12

def bewerte_iy(iy):
    """Bewertet das Flaechentraegheitsmoment."""
    if iy < 10_000:
        return "❌ zu gering"
    elif iy <= 50_000:
        return "✅ Zielbereich"
    else:
        return "⚠️ ueberdimensioniert"

print("  b x h [cm]  |   I_y [cm⁴]   | Bewertung")
print("  " + "-" * 48)

for b, h in querschnitte:
    iy = flaechentraegheitsmoment(b, h)
    bew = bewerte_iy(iy)
    print(f"  {b:>2} x {h:>2}      | {iy:>12,.0f}  | {bew}")

# %% [markdown]
# ---
# # Zusammenfassung
#
# | Konzept | Was es macht | Beispiel |
# |---------|-------------|----------|
# | `print()` | Text ausgeben | `print("Hallo")` |
# | Variablen | Werte speichern | `b = 12` |
# | Datentypen | `int`, `float`, `str`, `bool` | `7`, `3.14`, `"Text"`, `True` |
# | Operatoren | Rechnen | `+`, `-`, `*`, `/`, `**` |
# | f-String | Text formatieren | `f"b = {b} cm"` |
# | Vergleich | Werte vergleichen | `==`, `!=`, `<`, `>`, `<=`, `>=` |
# | `if/elif/else` | Entscheidungen | `if x > 0:` |
# | `for`-Schleife | Wiederholen | `for h in [16, 20, 24]:` |
# | Listen | Mehrere Werte | `[120, 85, 95]` |
# | Funktionen | Code wiederverwenden | `def f(x): return x**2` |
#
# ---
# *Digitales Bauen 1 | BFH AHB | Louis Trümpler*
